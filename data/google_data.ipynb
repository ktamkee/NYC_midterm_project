# %%
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
file = open('google_restaurants.json')
data = json.load(file)
data = pd.DataFrame(data).T
data
# Out:
#                    restaurant_counts  \
# nyu_2451_34572.1                [13]
# nyu_2451_34572.2                [12]
# nyu_2451_34572.3                [19]
# nyu_2451_34572.4                 [9]
# nyu_2451_34572.5                [14]
# ...                              ...
# nyu_2451_34572.302           [20, 0]
# nyu_2451_34572.303              [17]
# nyu_2451_34572.304               [0]
# nyu_2451_34572.305              [17]
# nyu_2451_34572.306               [5]
#
#                                              restaurant_review_counts  \
# nyu_2451_34572.1    [131, 23, 206, 179, 73, 897, 174, 111, 46, 199...
# nyu_2451_34572.2    [1158, 261, 496, 1777, 246, 5, 2967, 312, 1296...
# nyu_2451_34572.3    [1195, 20, 102, 271, 195, 0, 46, 629, 89, 402,...
# nyu_2451_34572.4           [446, 90, 488, 23, 48, 1130, 26, 173, 246]
# nyu_2451_34572.5    [537, 797, 282, 635, 289, 85, 0, 183, 519, 305...
# ...                                                               ...
# ...
