# %%
import pandas as pd
import numpy as np

# %%
# grab data
dbscan_v1 = pd.read_csv('../../data/clustering_data/dbscan_clusters.csv', index_col=0).drop('borough', axis=1)
dbscan_v2 = pd.read_csv('../../data/clustering_data/dbscan_v2_clusters.csv', index_col=0).drop('borough', axis=1)
dbscan_v3 = pd.read_csv('../../data/clustering_data/dbscan_v3_clusters.csv', index_col=0).drop('borough', axis=1)

k_means = pd.read_csv('../../data/clustering_data/dbscan_v3_clusters.csv', index_col=0)
k_means = pd.concat([k_means, dbscan_v3['population']], axis=1)

costs = pd.read_csv('../../data/evaluation_data/cluster_housing_costs.csv', index_col=0)

# %%
### We lost our evaluation notebook during a git misshap, this is a messy summary of what we used to compare models

# %%
k_means
# Out:
#            borough  neighborhood  longitude   latitude  population       PC1  \
# 0            Bronx     Wakefield -73.847201  40.894705     21242.0 -0.299939
# 1            Bronx    Co-op City -73.829939  40.874294     43752.0 -0.518157
# 2            Bronx   Eastchester -73.827806  40.887556     11506.0 -0.538953
# 3            Bronx     Fieldston -73.905643  40.895437      9287.0 -0.538112
# 4            Bronx     Riverdale -73.912585  40.890834      9287.0 -0.516148
# ..             ...           ...        ...        ...         ...       ...
# 301      Manhattan  Hudson Yards -74.000111  40.756658     23383.0  1.916515
# 302         Queens       Hammels -73.805530  40.587338     12295.0 -0.552061
# 303         Queens     Bayswater -73.765968  40.611322     25029.0 -0.866517
# 304         Queens  Queensbridge -73.945631  40.756091      6677.0  0.245570
# 305  Staten Island     Fox Hills -74.081740  40.617311     11230.0 -0.664190
#
# ...

# %%
# add economic data
dbscan_v1 = pd.concat([dbscan_v1, costs['average_costs']], axis=1)
dbscan_v2 = pd.concat([dbscan_v2, costs['average_costs']], axis=1)
dbscan_v3 = pd.concat([dbscan_v3, costs['average_costs']], axis=1)

# %%
print(dbscan_v1.groupby('cluster').count())
dbscan_v1.groupby('cluster').mean()
# Out:
#          longitude   latitude    population        PC1       PC2       PC3  \
# cluster
# -1      -73.933282  40.713757  37460.771429   5.585362  1.399156  2.458785
#  0      -73.946909  40.690106  23071.159624  -2.620104  0.201026 -0.241958
#  1      -73.887873  40.736051  27673.142857   0.412254 -6.145061  3.661836
#  2      -73.961644  40.733170  34109.227273   7.928630 -0.832916 -2.531712
#  3      -73.943017  40.739436  50038.933333   4.234434 -3.708215  0.434561
#  4      -74.000728  40.680500  44901.500000   6.083624 -1.190385  0.819004
#  5      -73.991163  40.752552  50666.666667  10.644198  3.605937 -2.017236
#  6      -73.932708  40.757945  29707.250000   8.390640  2.074956 -0.536672
#
#          average_costs
# cluster
# -1         3303.514286
#  0         1973.098592
#  1         1812.428571
#  2         4108.090909
#  3         2478.333333
#  4         4172.000000
#  5         5882.833333
#  6         5156.250000

# %%
print(dbscan_v2.groupby('cluster').count())
dbscan_v2.groupby('cluster').mean()
# Out:
#          longitude   latitude    population       PC1       PC2       PC3  \
# cluster
# -1      -73.900612  40.724131  40241.522388  0.408693  0.299501  0.018695
#  0      -73.964142  40.670669  20398.012500 -0.717822 -0.118199  0.060372
#  1      -73.893539  40.823177  37821.045455  0.316899  0.964776 -0.440367
#  2      -73.970194  40.684062  38889.454545  0.742695  0.319135 -0.015282
#  3      -73.979485  40.717591  32456.235294  1.355165 -0.513505  0.014437
#  4      -73.984485  40.741557  26800.478261  2.033330 -0.668409 -0.213613
#  5      -73.887611  40.650597  22423.333333  0.420549 -0.297892  0.601971
#
#               PC4       PC5  average_costs
# cluster
# -1      -0.052399  0.137871    2306.895522
#  0       0.015804  0.015084    1929.018750
#  1       0.278541 -0.539430    1765.727273
#  2      -0.118482  0.046258    3160.181818
#  3      -0.495856 -0.008149    4574.705882
#  4       0.264824  0.065184    5239.956522
#  5      -0.250637 -0.275470    2273.500000

# %%
print(dbscan_v3.groupby('cluster').count())
dbscan_v3.groupby('cluster').mean()
# Out:
#          neighborhood  longitude  latitude  population  PC1  PC2  PC3  PC4  \
# cluster
# -1                 66         66        66          66   66   66   66   66
#  0                157        157       157         157  157  157  157  157
#  1                 24         24        24          24   24   24   24   24
#  2                 19         19        19          19   19   19   19   19
#  3                 17         17        17          17   17   17   17   17
#  4                 23         23        23          23   23   23   23   23
#
#          PC5  average_costs
# cluster
# -1        66             66
#  0       157            157
#  1        24             24
#  2        19             19
#  3        17             17
#  4        23             23
#          longitude   latitude    population       PC1       PC2       PC3  \
# cluster
# -1      -73.907933  40.733989  38946.333333  0.407050  0.361861  0.015561
# ...

# %%
print(k_means.groupby('cluster').count())
k_means.groupby('cluster').mean()
# Out:
#          borough  neighborhood  longitude  latitude  population  PC1  PC2  \
# cluster
# -1            66            66         66        66          66   66   66
#  0           157           157        157       157         157  157  157
#  1            24            24         24        24          24   24   24
#  2            19            19         19        19          19   19   19
#  3            17            17         17        17          17   17   17
#  4            23            23         23        23          23   23   23
#
#          PC3  PC4  PC5  population
# cluster
# -1        66   66   66          66
#  0       157  157  157         157
#  1        24   24   24          24
#  2        19   19   19          19
#  3        17   17   17          17
#  4        23   23   23          23
#          longitude   latitude    population       PC1       PC2       PC3  \
# cluster
# -1      -73.907933  40.733989  38946.333333  0.407050  0.361861  0.015561
# ...
